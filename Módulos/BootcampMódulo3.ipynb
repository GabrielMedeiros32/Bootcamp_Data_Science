# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMedeiros32/Bootcamp_Data_Science/blob/main/M%C3%B3dulos/BootcampM%C3%B3dulo3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Módulo 3**

# %% [markdown]
# ##**Aula 1**

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
import matplotlib.ticker as ticker

# %%
url = 'https://github.com/GabrielMedeiros32/Bootcamp_Data_Science/raw/main/Dados/dados_covid_sp.zip'

# %%
dados = pd.read_csv(url,sep=';')
dados
# Out:
#               nome_munic  codigo_ibge  dia  ...  latitude longitude  semana_epidem
# 0             Adamantina      3500105   25  ...  -21,6820  -51,0737              9
# 1                 Adolfo      3500204   25  ...  -21,2325  -49,6451              9
# 2                  Aguaí      3500303   25  ...  -22,0572  -46,9735              9
# 3         Águas da Prata      3500402   25  ...  -21,9319  -46,7176              9
# 4       Águas de Lindóia      3500501   25  ...  -22,4733  -46,6314              9
# ...                  ...          ...  ...  ...       ...       ...            ...
# 286173          Ignorado      9999999    8  ...    0,0000    0,0000             18
# 286174          Ignorado      9999999    9  ...    0,0000    0,0000             19
# 286175          Ignorado      9999999   10  ...    0,0000    0,0000             19
# 286176          Ignorado      9999999   11  ...    0,0000    0,0000             19
# ...

# %%
mpl.rcParams['font.size'] = 12
mpl.rcParams['figure.figsize'] = (10,6)

# %%
#sns.lineplot(x='datahora',y='casos',data=dados)

# %%
dados['datahora']= pd.to_datetime(dados['datahora'], format='%Y-%m-%d')
dados.head()
# Out:
#          nome_munic  codigo_ibge  dia  ...  latitude longitude  semana_epidem
# 0        Adamantina      3500105   25  ...  -21,6820  -51,0737              9
# 1            Adolfo      3500204   25  ...  -21,2325  -49,6451              9
# 2             Aguaí      3500303   25  ...  -22,0572  -46,9735              9
# 3    Águas da Prata      3500402   25  ...  -21,9319  -46,7176              9
# 4  Águas de Lindóia      3500501   25  ...  -22,4733  -46,6314              9
#
# [5 rows x 26 columns]

# %%
#sns.lineplot(x='datahora',y='casos',data=dados)

# %%
eixo_x = np.linspace(-2,2,100)
y_exp = np.exp(eixo_x)

# %%
sns.lineplot(x=eixo_x,y=y_exp)

# %%
sns.lineplot(x=eixo_x, y=y_exp)
mpl.pyplot.yscale('log')

# %%
dados_sp = dados.query('nome_munic == "São Paulo"')
dados_sp.head()
# Out:
#      nome_munic  codigo_ibge  dia  ...  latitude longitude  semana_epidem
# 562   São Paulo      3550308   25  ...  -23,5329  -46,6395              9
# 1207  São Paulo      3550308   26  ...  -23,5329  -46,6395              9
# 1852  São Paulo      3550308   27  ...  -23,5329  -46,6395              9
# 2497  São Paulo      3550308   28  ...  -23,5329  -46,6395              9
# 3142  São Paulo      3550308   29  ...  -23,5329  -46,6395              9
#
# [5 rows x 26 columns]

# %%
sns.lineplot(x='datahora', y='casos', data=dados_sp)

# %%
sns.lineplot(x='datahora', y='casos', data=dados_sp)
mpl.pyplot.yscale('log')

# %%
sns.lineplot(x='datahora',y='casos_novos',data=dados_sp)

# %%
dados_exemplo = pd.DataFrame(data=np.linspace(1,10,10))

# %%
sns.lineplot(x=0,y=0,data=dados_exemplo)

# %%
dados_exemplo['diferenciado'] = dados_exemplo.diff()

# %%
sns.lineplot(x=0,y=0,data=dados_exemplo)
sns.lineplot(x=0,y='diferenciado',data=dados_exemplo)

# %%
dados_sp['taxa_de_crescimento_casos'] = dados_sp['casos_novos'].diff()
dados_sp['taxa_de_crescimento_obitos'] = dados_sp['obitos_novos'].diff()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.lineplot(x='datahora', y='taxa_de_crescimento_casos',data=dados_sp)

# %%
sns.lineplot(x='datahora',y='taxa_de_crescimento_obitos',data=dados_sp)

# %%
plt.bar(dados_sp['datahora'],dados_sp['taxa_de_crescimento_casos'])
# Out:
# <BarContainer object of 443 artists>

# %%
dados_sp['ano'] = pd.DatetimeIndex(dados_sp['datahora']).year
dados_2021 = dados_sp.query('ano==2021')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.bar(dados_2021['datahora'],dados_2021['taxa_de_crescimento_casos'])
# Out:
# <BarContainer object of 132 artists>

# %%
dados_sp['media_movel_casos']=dados_sp['casos_novos'].rolling(window=7, center=False).mean()
dados_sp['media_movel_obitos']=dados_sp['obitos_novos'].rolling(window=7, center=False).mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
sns.lineplot(x='datahora',y='casos_novos',data=dados_sp)
sns.lineplot(x='datahora',y='media_movel_casos',data=dados_sp)

# %%
sns.lineplot(x='casos_novos',y='casos_novos',data=dados_sp)

# %%
sns.lineplot(x='casos_novos',y='obitos_novos',data=dados_sp)

# %%
dados_202101 = dados_sp.query('mes==1 & ano==2021')
dados_202102 = dados_sp.query('mes==2 & ano==2021')

# %%
plt.bar(np.linspace(1,31,31),dados_202101['casos_novos'])
# Out:
# <BarContainer object of 31 artists>

# %%
autocorrelation_plot(dados_sp['casos_novos'])

# %%
aleatorio = np.random.rand(443)
autocorrelation_plot(aleatorio)

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 1** - Um notebook sem warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Desafio 2** - Pico taxa de casos novos coincide com taxa dos óbitos novos.

# %%
dados_sp['taxa_de_crescimento_media_movel_obitos'] = dados_sp['media_movel_obitos'].diff()

# %%
g1 = sns.lineplot(x='datahora', y='taxa_de_crescimento_casos', data=dados_202101)
ax2 = plt.twinx()
g2 = sns.lineplot(x='datahora', y='taxa_de_crescimento_obitos', data=dados_202101, color='r', ax=ax2)
plt.grid(linestyle="--", linewidth=0.4, color='black')
plt.locator_params(axis='y', nbins=13)

plt.show()

# %% [markdown]
# **Desafio 3** - Fazer melhorias nos gráficos

# %%
plt.figure(figsize=(20,8))

ax = sns.lineplot(x='datahora',y='obitos_novos',data=dados_sp).set_title('Novos óbitos e média móvel - SP', fontsize=20, weight=(700))
ax2 = sns.lineplot(x='datahora',y='media_movel_obitos',data=dados_sp)
ax2.xaxis.set_major_locator(ticker.IndexLocator(base=30, offset=0))

plt.legend(title='COVID em SP', labels=('Nº de óbitos Novos','Média móvel de óbitos - 7 dias'))
plt.ylabel('Casos novos e média móvel de óbitos', fontsize=18, weight=(700)) 
plt.xlabel('Ano-mês', fontsize=18, weight=(700))
plt.ylim(0,400)

plt.xticks(rotation=30, fontsize=16)
plt.yticks(fontsize=16, rotation=30)
plt.locator_params(axis='y', nbins=17)
plt.grid(linestyle="--", linewidth=0.4, color='black')
plt.show()

# %% [markdown]
# **Desafio 4** - Gerar o gráfico da média móvel do número de óbitos e mudar os gráficos de casos para barras.

# %%
sns.lineplot(x='datahora',y='obitos_novos',data=dados_sp)
sns.lineplot(x='datahora',y='media_movel_obitos',data=dados_sp)

# %%
plt.bar(dados_sp['datahora'], dados_sp['media_movel_casos'], width=1.5)
# Out:
# <BarContainer object of 443 artists>

# %% [markdown]
# **Desafio 5** - Mover o número de óbitos alguns dias para verificar o resultado no gráfico.

# %%
dados_dias = dados_sp.copy()
dados_dias['obitos_-42_dias']= dados_sp['obitos_novos'].shift(-42)
dados_dias['obitos_-35_dias']= dados_sp['obitos_novos'].shift(-35)
dados_dias['obitos_-28_dias']= dados_sp['obitos_novos'].shift(-28)
dados_dias['obitos_-21_dias']= dados_sp['obitos_novos'].shift(-21)
dados_dias['obitos_-14_dias'] = dados_sp['obitos_novos'].shift(-14)
dados_dias['obitos_-8_dias'] = dados_sp['obitos_novos'].shift(-8)
dados_dias['obitos_-7_dias'] = dados_sp['obitos_novos'].shift(-7)
dados_dias['obitos_-6_dias'] = dados_sp['obitos_novos'].shift(-6)
dados_dias['obitos_-5_dias'] = dados_sp['obitos_novos'].shift(-5)
dados_dias['obitos_-4_dias'] = dados_sp['obitos_novos'].shift(-4)
dados_dias['obitos_-3_dias'] = dados_sp['obitos_novos'].shift(-3)
dados_dias['obitos_-2_dias'] = dados_sp['obitos_novos'].shift(-2)
dados_dias['obitos_-1_dias'] = dados_sp['obitos_novos'].shift(-1)
dados_dias['obitos_1_dias'] = dados_sp['obitos_novos'].shift(1)
dados_dias['obitos_2_dias'] = dados_sp['obitos_novos'].shift(2)
dados_dias['obitos_3_dias'] = dados_sp['obitos_novos'].shift(3)
dados_dias['obitos_7_dias'] = dados_sp['obitos_novos'].shift(7)
dados_dias['obitos_14_dias']= dados_sp['obitos_novos'].shift(14)
dados_dias['obitos_21_dias']= dados_sp['obitos_novos'].shift(21)
dados_dias['obitos_28_dias']= dados_sp['obitos_novos'].shift(28)
dados_dias['obitos_35_dias']= dados_sp['obitos_novos'].shift(35)
dados_dias['obitos_42_dias']= dados_sp['obitos_novos'].shift(42)

# %%
dados_dias[['casos_novos', 'obitos_novos', 'obitos_-1_dias','obitos_-3_dias','obitos_-5_dias','obitos_-6_dias','obitos_-7_dias','obitos_-8_dias','obitos_-14_dias', 'obitos_-21_dias', 'obitos_-28_dias', 'obitos_-35_dias','obitos_1_dias','obitos_2_dias','obitos_3_dias','obitos_7_dias', 'obitos_14_dias','obitos_21_dias','obitos_28_dias', 'obitos_35_dias']].corr()
# Out:
#                  casos_novos  obitos_novos  ...  obitos_28_dias  obitos_35_dias
# casos_novos         1.000000      0.735532  ...        0.489378        0.463249
# obitos_novos        0.735532      1.000000  ...        0.587961        0.502487
# obitos_-1_dias      0.484897      0.571047  ...        0.395037        0.299838
# obitos_-3_dias      0.193136      0.346219  ...        0.118915        0.023535
# obitos_-5_dias      0.288554      0.355330  ...        0.142197        0.067100
# obitos_-6_dias      0.509140      0.574461  ...        0.276526        0.217231
# obitos_-7_dias      0.681051      0.818991  ...        0.502487        0.438711
# obitos_-8_dias      0.479266      0.555180  ...        0.299838        0.229123
# obitos_-14_dias     0.644998      0.750987  ...        0.438711        0.374369
# obitos_-21_dias     0.562852      0.682405  ...        0.374369        0.314584
# obitos_-28_dias     0.505810      0.587961  ...        0.314584        0.255736
# ...

# %% [markdown]
# **Desafio 6** - Função de correlação cruzada dos óbitos e casos.

# %%
plt.title("Correlação entre casos novos e óbitos novos por lag - Método plt.xcorr - para o período de 10/2020 a 04/2021")
plt.xcorr(x = dados_sp.loc[:,"casos_novos"].astype(float), y = dados_sp.loc[:,"obitos_novos"].astype(float),
          maxlags = None, usevlines = False, linestyle = "-")
plt.grid()
plt.ylabel("Índice de Correlação")
plt.xlabel("Lag")
plt.show()

# %% [markdown]
# **Desafio 7** - Estudar outros municípios.

# %% [markdown]
# ##**Aula 2**

# %%
from fbprophet import Prophet

# %%
df = pd.DataFrame()

# %%
df['ds'] = dados_sp['datahora']
df['y'] = dados_sp['casos_novos']

# %%
modelo = Prophet()

# %%
modelo.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dataframefuturo = modelo.make_future_dataframe(periods=30)

# %%
dataframefuturo.head()
# Out:
#           ds
# 0 2020-02-25
# 1 2020-02-26
# 2 2020-02-27
# 3 2020-02-28
# 4 2020-02-29

# %%
previsao = modelo.predict(dataframefuturo)

# %%
previsao.head()
# Out:
#           ds       trend  ...  multiplicative_terms_upper        yhat
# 0 2020-02-25 -114.303728  ...                         0.0  386.013224
# 1 2020-02-26  -96.932780  ...                         0.0  457.834930
# 2 2020-02-27  -79.561833  ...                         0.0  571.148167
# 3 2020-02-28  -62.190885  ...                         0.0  306.251181
# 4 2020-02-29  -44.819937  ...                         0.0  -13.995200
#
# [5 rows x 16 columns]

# %%
modelo.plot(previsao,xlabel='Data',ylabel='Casos novos',figsize=(20,10));

# %%
df = pd.DataFrame()

# %%
df['ds'] = dados_sp['datahora'][:400]
df['y'] = dados_sp['casos_novos'][:400]

# %%
modelo = Prophet(n_changepoints=25, changepoint_prior_scale=10)

# %%
modelo.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dataframefuturo = modelo.make_future_dataframe(periods=43)

# %%
previsao = modelo.predict(dataframefuturo)

# %%
df_teste = pd.DataFrame()
df_teste['ds'] = dados_sp['datahora'][400:]
df_teste['y'] = dados_sp['casos_novos'][400:]

# %%
modelo.plot(previsao,xlabel='Data',ylabel='Casos novos',figsize=(20,10));
plt.plot(df_teste['ds'],df_teste['y'], '.r')

# %%
modelo.plot_components(previsao,figsize=(20,10));

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 8** - Mudar os períodos de previsão.

# %% [markdown]
# **Desafio 9** - Explorar a documentação do Prophet e melhorar os gráficos.

# %% [markdown]
# **Desafio 10** - Fazer todo o processo de previsão para o número de casos acumulados.

# %% [markdown]
# ##**Aula 3**

# %%
from fbprophet.plot import add_changepoints_to_plot

# %%
fig = modelo.plot(previsao,figsize=(14,7))
a = add_changepoints_to_plot(fig.gca(),modelo,previsao)

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 11** -  Identificar potenciais changepoints.

# %% [markdown]
# **Desafio 12** - Desenvolver uma função roda o modelo automaticamente.

# %% [markdown]
# ##**Aula 4**

# %%
feriados_sp_2020= [
'2020-02-25',
'2020-02-26',
'2020-04-10',
'2020-04-21',
'2020-05-01',
'2020-05-20',
'2020-05-21',
'2020-05-22',
'2020-05-25',
'2020-06-11',
'2020-09-07',
'2020-10-12',
'2020-11-02',
'2020-11-15',
'2020-12-25'
]

feriados_sp_2021= [
'2020-01-01',
'2020-01-25',
'2020-02-15',
'2020-02-16',
'2020-02-17',
'2020-03-26',
'2020-03-29',
'2020-03-30',
'2020-03-31',
'2020-04-01',
'2020-04-02',
'2020-4-21',
'2020-05-01'
]

# %%
feriados_sp_2020 = pd.DataFrame({'holiday': 'sp_2020', 'ds': pd.to_datetime(feriados_sp_2020)})

# %%
feriados_sp_2021 = pd.DataFrame({'holiday': 'sp_2021', 'ds': pd.to_datetime(feriados_sp_2021)})

# %%
feriados = pd.concat((feriados_sp_2020, feriados_sp_2021))

# %%
df = pd.DataFrame()

# %%
df['ds'] = dados_sp['datahora'][:400]
df['y'] = dados_sp['casos_novos'][:400]

# %%
modelo_feriados = Prophet(changepoint_prior_scale=10,holidays=feriados,seasonality_mode='multiplicative')

# %%
#modelo_feriados.add_country_holidays(country_name='BR')

# %%
modelo_feriados.fit(df)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
dataframefuturo = modelo_feriados.make_future_dataframe(periods=43)

# %%
previsao = modelo_feriados.predict(dataframefuturo)

# %%
df_teste = pd.DataFrame()
df_teste['ds'] = dados_sp['datahora'][400:]
df_teste['y'] = dados_sp['casos_novos'][400:]

# %%
modelo_feriados.plot(previsao,xlabel='Data',ylabel='Casos novos',figsize=(20,10));
plt.plot(df_teste['ds'],df_teste['y'], '.r')

# %%
modelo_feriados.plot_components(previsao,figsize=(14,8));

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(df['y'],previsao['yhat'][:400])
# Out:
# 452.2884903942229

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio Extra** - Utilizar outras métricas do Scikitlearn e comparar os resultados.

# %% [markdown]
# ##**Aula 5**

# %%
novo_y = df.reset_index()

# %%
sem_outliers = novo_y[(novo_y['y']> previsao['yhat_lower'][:400]) & (novo_y['y'] < previsao['yhat_upper'][:400])]

# %%
plt.plot(df.index, df['y'], 'r.')
plt.plot(sem_outliers['index'], sem_outliers['y'])

# %%
df_sem_outliers = sem_outliers[['ds','y']]
df_sem_outliers.head()
# Out:
#           ds  y
# 0 2020-02-25  0
# 1 2020-02-26  0
# 2 2020-02-27  0
# 3 2020-02-28  1
# 4 2020-02-29  0

# %%
modelo_feriados = Prophet(changepoint_prior_scale=10.0, holidays=feriados, seasonality_mode='multiplicative')
modelo_feriados.fit(df_sem_outliers)
dataframefuturo = modelo_feriados.make_future_dataframe(periods=43)
previsao = modelo_feriados.predict(dataframefuturo)
fig = modelo_feriados.plot(previsao, figsize=(15,10))
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
modelo_feriados.plot_components(previsao);

# %%
amostras = modelo_feriados.predictive_samples(previsao)

# %%
plt.plot(previsao['ds'],amostras['trend']);

# %%
from fbprophet.diagnostics import cross_validation

# %%
df_cv =cross_validation(modelo_feriados,initial='180 days',period='30 days',horizon='30 days')
# Out:
# INFO:fbprophet:Making 7 forecasts with cutoffs between 2020-08-31 00:00:00 and 2021-02-27 00:00:00
# ...

# %%
janela = 1

# %%
df_cv.head()
# Out:
#           ds         yhat   yhat_lower   yhat_upper     y     cutoff
# 0 2020-09-02  1898.695357  1491.719571  2301.987069  1579 2020-08-31
# 1 2020-09-03  1952.115885  1515.369332  2398.457434  2496 2020-08-31
# 2 2020-09-04  1962.217675  1503.436625  2409.888579  1166 2020-08-31
# 3 2020-09-05  1526.928055  1050.443153  1959.933800  1245 2020-08-31
# 4 2020-09-06   632.250053   226.616154  1065.691002   290 2020-08-31

# %%
cutoff = df_cv['cutoff'].unique()[janela]

# %%
df_cv_cut = df_cv[df_cv['cutoff'].values == cutoff]

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
ax.plot(modelo_feriados.history['ds'].values, modelo_feriados.history['y'], 'k.')
ax.plot(df_cv_cut['ds'].values, df_cv_cut['yhat'], ls='-', c='#0072B2')
ax.fill_between(df_cv_cut['ds'].values, df_cv_cut['yhat_lower'],
                df_cv_cut['yhat_upper'], color='blue', alpha=0.2)
ax.axvline(x=pd.to_datetime(cutoff), c='gray', lw=4, alpha=0.5)
ax.set_ylabel('y')
ax.set_xlabel('ds')
# Out:
# Text(0.5, 0, 'ds')

# %%
from fbprophet.diagnostics import performance_metrics

# %%
df_p = performance_metrics(df_cv)
# Out:
# INFO:fbprophet:Skipping MAPE because y close to 0

# %%
df_p
# Out:
#    horizon           mse         rmse         mae     mdape  coverage
# 0   3 days  7.729522e+04   278.020174  198.513832  0.174865  0.833333
# 1   4 days  1.257703e+05   354.641016  281.377447  0.199562  0.777778
# 2   5 days  1.217891e+05   348.983022  282.769523  0.193974  0.825397
# 3   6 days  1.266061e+05   355.817523  293.148546  0.217930  0.796296
# 4   7 days  8.052123e+04   283.762631  238.320876  0.118658  0.888889
# 5   8 days  1.605979e+05   400.746714  321.844775  0.172077  0.722222
# 6   9 days  1.566698e+05   395.815369  315.250619  0.148978  0.722222
# 7  10 days  1.671693e+05   408.863381  343.770782  0.260041  0.722222
# 8  11 days  1.004619e+05   316.957221  283.018936  0.169346  0.904762
# 9  12 days  1.057869e+05   325.248936  261.289951  0.146582  0.944444
# 10 13 days  1.932306e+05   439.580011  327.739308  0.221349  0.833333
# 11 14 days  2.426488e+05   492.593968  377.914252  0.190180  0.738095
# ...

# %%
from fbprophet.plot import plot_cross_validation_metric

# %%
plot_cross_validation_metric(df_cv,metric='rmse');

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 13** - Testar diferentes intervalos de confiança.

# %% [markdown]
# **Desafio 14** - Buscar quais métricas se aplicam a quais casos.

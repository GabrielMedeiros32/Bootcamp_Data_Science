# %% [markdown]
# <a href="https://colab.research.google.com/github/GabrielMedeiros32/Bootcamp_Data_Science/blob/main/M%C3%B3dulos/BootcampM%C3%B3dulo4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Módulo 4**

# %% [markdown]
# ##**Aula 1**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##**Aula 2**

# %%
dados = pd.read_excel("https://github.com/GabrielMedeiros32/Bootcamp_Data_Science/raw/main/Dados/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx")

# %%
dados.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1925.000000  ...  1925.000000
# mean                 192.000000  ...     0.267532
# std                  111.168431  ...     0.442787
# min                    0.000000  ...     0.000000
# 25%                   96.000000  ...     0.000000
# 50%                  192.000000  ...     0.000000
# 75%                  288.000000  ...     1.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
dados['ICU'].value_counts()
# Out:
# 0    1410
# 1     515
# Name: ICU, dtype: int64

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 1** - Pesquisar aprendizado supervisionado, não supervisionado, por reforço e mais (forma).

# %% [markdown]
# **Desafio 2** - Pesquisar sobre classificação, regressão e outros problemas que podem ser solucionados com Machine Learning.

# %% [markdown]
# ## **Aula 3**

# %%
x_columns = dados.describe().columns
dados_limpos = dados.dropna()

# %%
y = dados_limpos['ICU']
x = dados_limpos[x_columns].drop(['ICU'], axis = 1)

# %%
from sklearn.linear_model import LogisticRegression

modelo = LogisticRegression()
modelo.fit(x,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
modelo.predict([x.iloc[4]])
# Out:
# array([1])

# %%
y.iloc[4]
# Out:
# 1

# %%
sum(modelo.predict(x) == y)
# Out:
# 497

# %%
sum(modelo.predict(x) != y)
# Out:
# 48

# %%
acuracy = sum(modelo.predict(x) == y) / len(y) * 100
acuracy
# Out:
# 91.19266055045871

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 3** - Qual o motivo de jogar fora o ICU do dado X? O que acontece se estiver no x? Pq seria bom/ruim? .

# %% [markdown]
# **Desafio 4** - Pesquisar sobre ética em data science/ciência de dados e inteligência artificial .

# %% [markdown]
# ##**Aula 4**

# %%
y.value_counts()
# Out:
# 0    281
# 1    264
# Name: ICU, dtype: int64

# %%
from sklearn.dummy import DummyClassifier

modelo_2 = DummyClassifier('most_frequent')
modelo_2.fit(x,y)
sum(modelo_2.predict(x) == y) / len(y) * 100
# Out:
# 51.559633027522935

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y, modelo_2.predict(x))
# Out:
# 0.5155963302752293

# %%
np.random.seed(73246)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)

# %%
modelo = LogisticRegression()
modelo.fit(x_train, y_train)
y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.8248175182481752

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.514706
# 1    0.485294
# Name: ICU, dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.518248
# 1    0.481752
# Name: ICU, dtype: float64

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Desafio 5** - Decida quanto você vai escolher para treino e quanto para teste? Quanto as pessoas utilizam e qual o motivo?

# %% [markdown]
# **Desafio 6** - Olhe a documentação da LogisticRegression... o que tem de parâmetro em comum com o train_test_split? O que isso significa pra nós? .

# %% [markdown]
# ##**Aula 5**

# %%
dados_fake = pd.DataFrame([[1, None, 1],[1, 2.5, 2],
                           [2, 3.0, 1],[2, None, 2],
                          [3, None, 1],[3, 1.0, 2],[3, None, 3],
                           [4, None, 1],[4, 6.0, 2],[4, None, 3],[4, 5.0, 4]], columns=['usuario','medida','janela'])
dados_fake
# Out:
#     usuario  medida  janela
# 0         1     NaN       1
# 1         1     2.5       2
# 2         2     3.0       1
# 3         2     NaN       2
# 4         3     NaN       1
# 5         3     1.0       2
# 6         3     NaN       3
# 7         4     NaN       1
# 8         4     6.0       2
# 9         4     NaN       3
# 10        4     5.0       4

# %%
dados_fake.groupby('usuario', as_index=False)['medida'].fillna(method='ffill').fillna(method='bfill')
# Out:
#     medida
# 0      2.5
# 1      2.5
# 2      3.0
# 3      3.0
# 4      1.0
# 5      1.0
# 6      1.0
# 7      6.0
# 8      6.0
# 9      6.0
# 10     5.0

# %%
dados = pd.read_excel("https://github.com/GabrielMedeiros32/Bootcamp_Data_Science/raw/main/Dados/Kaggle_Sirio_Libanes_ICU_Prediction.xlsx")
dados.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
features_continuas = dados.iloc[:, 13:-2].columns
features_continuas
# Out:
# Index(['ALBUMIN_MEDIAN', 'ALBUMIN_MEAN', 'ALBUMIN_MIN', 'ALBUMIN_MAX',
#        'ALBUMIN_DIFF', 'BE_ARTERIAL_MEDIAN', 'BE_ARTERIAL_MEAN',
#        'BE_ARTERIAL_MIN', 'BE_ARTERIAL_MAX', 'BE_ARTERIAL_DIFF',
#        ...
#        'HEART_RATE_DIFF', 'RESPIRATORY_RATE_DIFF', 'TEMPERATURE_DIFF',
#        'OXYGEN_SATURATION_DIFF', 'BLOODPRESSURE_DIASTOLIC_DIFF_REL',
#        'BLOODPRESSURE_SISTOLIC_DIFF_REL', 'HEART_RATE_DIFF_REL',
#        'RESPIRATORY_RATE_DIFF_REL', 'TEMPERATURE_DIFF_REL',
#        'OXYGEN_SATURATION_DIFF_REL'],
#       dtype='object', length=216)

# %%
def preenche_tabela(dados):
    features_continuas_colunas = dados.iloc[:, 13:-2].columns
    features_continuas = dados.groupby('PATIENT_VISIT_IDENTIFIER', as_index=False)[features_continuas_colunas].fillna(method='bfill').fillna(method='ffill')
    features_categoricas = dados.iloc[:, :13]
    saida = dados.iloc[:,-2:]
    dados_finais = pd.concat([features_categoricas, features_continuas, saida], ignore_index=True, axis=1)
    dados_finais.columns = dados.columns
    return dados_finais

# %%
dados_limpos = preenche_tabela(dados)
dados_limpos.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1925.000000  ...  1925.000000
# mean                 192.000000  ...     0.267532
# std                  111.168431  ...     0.442787
# min                    0.000000  ...     0.000000
# 25%                   96.000000  ...     0.000000
# 50%                  192.000000  ...     0.000000
# 75%                  288.000000  ...     1.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
dados_limpos = dados_limpos.dropna()

# %%
a_remover = dados_limpos.query("WINDOW == '0-2' and ICU == 1")['PATIENT_VISIT_IDENTIFIER'].values
dados_limpos = dados_limpos.query("PATIENT_VISIT_IDENTIFIER not in @a_remover")
dados_limpos.describe()
# Out:
#        PATIENT_VISIT_IDENTIFIER  ...          ICU
# count               1760.000000  ...  1760.000000
# mean                 192.818182  ...     0.201705
# std                  110.637724  ...     0.401387
# min                    0.000000  ...     0.000000
# 25%                   97.750000  ...     0.000000
# 50%                  191.500000  ...     0.000000
# 75%                  289.250000  ...     0.000000
# max                  384.000000  ...     1.000000
#
# [8 rows x 229 columns]

# %%
def prepara_window(rows):
    if(np.any(rows['ICU'])):
      rows.loc[rows['WINDOW'] == '0-2', 'ICU'] = 1
    return rows.loc[rows['WINDOW']=='0-2']

# %%
dados_limpos.groupby('PATIENT_VISIT_IDENTIFIER').apply(prepara_window)
dados_limpos.head()
# Out:
#    PATIENT_VISIT_IDENTIFIER  AGE_ABOVE65  ...    WINDOW  ICU
# 0                         0            1  ...       0-2    0
# 1                         0            1  ...       2-4    0
# 2                         0            1  ...       4-6    0
# 3                         0            1  ...      6-12    0
# 4                         0            1  ...  ABOVE_12    1
#
# [5 rows x 231 columns]

# %%
y = dados_limpos['ICU']
x = dados_limpos[x_columns].drop(['ICU'], axis = 1)

# %%
np.random.seed(73246)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y)

# %%
modelo_2 = DummyClassifier('most_frequent')
modelo_2.fit(x_train, y_train)

y_prediction = modelo_2.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# 0.7977272727272727

# %%
modelo = LogisticRegression()
modelo.fit(x_train, y_train)

y_prediction = modelo.predict(x_test)
accuracy_score(y_test, y_prediction)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# 0.875

# %% [markdown]
# ###**Desafios**

# %% [markdown]
# **Super desafio 6** - não usar backfill da janela após a pessoa ter ido pra UTI

# %% [markdown]
# **Desafio 7** - Arranque fora as colunas que não devem ser utilizadas.

# %% [markdown]
# **Desafio 8** - Essa aula não foi simples, repasse por ela e garanta que entendeu passo a passo.
